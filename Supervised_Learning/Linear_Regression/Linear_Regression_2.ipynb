# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install scikit-learn
# Out:
# ...
#   Using cached matplotlib-3.10.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached contourpy-1.3.1-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.55.3-cp312-cp312-win_amd64.whl.metadata (168 kB)
# ...
#   Using cached kiwisolver-1.4.8-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# ...
#   Using cached pillow-11.1.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# ...
#   Using cached pyparsing-3.2.1-py3-none-any.whl.metadata (5.0 kB)
# ...
# Using cached matplotlib-3.10.0-cp312-cp312-win_amd64.whl (8.0 MB)
# Using cached contourpy-1.3.1-cp312-cp312-win_amd64.whl (220 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.55.3-cp312-cp312-win_amd64.whl (2.2 MB)
# Using cached kiwisolver-1.4.8-cp312-cp312-win_amd64.whl (71 kB)
# Using cached pillow-11.1.0-cp312-cp312-win_amd64.whl (2.6 MB)
# Using cached pyparsing-3.2.1-py3-none-any.whl (107 kB)
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %% [markdown]
# <br><br>
# ### Read dataset

# %%
data = pd.read_csv("./dataset/dataset_2.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   5 non-null      object
#  1   videos       5 non-null      int64
#  2   days         5 non-null      int64
#  3   subscribers  5 non-null      int64
#  4   views        5 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 332.0+ bytes

# %% [markdown]
# <br><br>
# ### Train Model (to find best fit line)

# %%
# Create LinearRegression model obj
model = LinearRegression()

# Train
model.fit(x, y)
# Out:
# LinearRegression()

# %%
model.predict([[45, 180, 3100]])
# Out:
# array([41483.5043287])

# %%
# m
m = model.coef_
m
# Out:
# array([3.81732131e+02, 4.21209097e+01, 3.54006782e-01])

# %%
# c
c = model.intercept_
c
# Out:
# np.float64(15626.373669488301)

# %%
# y = m1 * x1 + m2 * x2 + m3 * x3 + c
y_new = m[0] * 45 + m[1] * 180 + m[2] * 3100 + c
y_new
# Out:
# np.float64(41483.504328703)
